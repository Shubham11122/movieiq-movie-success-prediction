# %%
import sys

# !{sys.executable} -m pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: plotly in C:\Users\user\AppData\Roaming\Python\Python311\site-packages (6.9.0)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Users\user\AppData\Roaming\Python\Python311\site-packages (from plotly) (2.24.0)
# Requirement already satisfied: packaging in e:\anaconda\envs\data_analyst\Lib\site-packages (from plotly) (26.0)

# %%
import sys

print("Python Executable:")
print(sys.executable)

print("\nPython Version:")
print(sys.version)

import plotly
print("\nPlotly Version:", plotly.__version__)
print("Plotly Location:", plotly.__file__)
# Out:
# Python Executable:
# e:\anaconda\envs\data_analyst\python.exe
#
# Python Version:
# 3.11.15 | packaged by Anaconda, Inc. | (main, Mar 11 2026, 17:12:15) [MSC v.1942 64 bit (AMD64)]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 9
#       5
#       6 print("\nPython Version:")
#       7 print(sys.version)
#       8
# ----> 9 import plotly
#      10 print("\nPlotly Version:", plotly.__version__)
#      11 print("Plotly Location:", plotly.__file__)
#
# ModuleNotFoundError: No module named 'plotly'
